# %%
import pandas as pd

# %%
df2 = pd.read_csv('Uncleaned_DS_jobs.csv')

# %%
df2.head()
# Out:
#    index          Job Title               Salary Estimate  \
# 0      0  Sr Data Scientist  $137K-$171K (Glassdoor est.)
# 1      1     Data Scientist  $137K-$171K (Glassdoor est.)
# 2      2     Data Scientist  $137K-$171K (Glassdoor est.)
# 3      3     Data Scientist  $137K-$171K (Glassdoor est.)
# 4      4     Data Scientist  $137K-$171K (Glassdoor est.)
#
#                                      Job Description  Rating  \
# 0  Description\n\nThe Senior Data Scientist is re...     3.1
# 1  Secure our Nation, Ignite your Future\n\nJoin ...     4.2
# 2  Overview\n\n\nAnalysis Group is one of the lar...     3.8
# 3  JOB DESCRIPTION:\n\nDo you have a passion for ...     3.5
# 4  Data Scientist\nAffinity Solutions / Marketing...     2.9
#
#               Company Name       Location            Headquarters  \
# 0         Healthfirst\n3.1   New York, NY            New York, NY
# 1             ManTech\n4.2  Chantilly, VA             Herndon, VA
# ...

# %%
df2.columns
# Out:
# Index(['index', 'Job Title', 'Salary Estimate', 'Job Description', 'Rating',
#        'Company Name', 'Location', 'Headquarters', 'Size', 'Founded',
#        'Type of ownership', 'Industry', 'Sector', 'Revenue', 'Competitors'],
#       dtype='object')

# %%
#Salary parsing (regex; lambda function)

df2 = df2[df2['Salary Estimate'] != '-1']

df2['hourly'] = df2['Salary Estimate'].apply(lambda x: 1 if 'per hour' in x.lower() else 0)
df2['employer_provided'] = df2['Salary Estimate'].apply(lambda x: 1 if 'employer provided salary' in x.lower() else 0)

#extracts the range
salary = df2['Salary Estimate']
salary = df2['Salary Estimate'].apply(lambda x: x.split('(')[0])

#remove the K and the $
minus_Kd = salary.apply(lambda x: x.replace('K', '').replace('$', ''))

#remove the 'per hour' and 'emp...' from some cells
min_hr = minus_Kd.apply(lambda x: x.replace('per hour', '').replace('employer provided salary', ''))

#create new columns for min & max salary
df2['min_salary'] = min_hr.apply(lambda x: int(x.split('-')[0]))
df2['max_salary'] = min_hr.apply(lambda x: int(x.split('-')[1]))

#create a column for avg salary
df2['avg_salary'] = (df2.min_salary + df.max_salary)/2
df2.head()
# Out:
#    index          Job Title               Salary Estimate  \
# 0      0  Sr Data Scientist  $137K-$171K (Glassdoor est.)
# 1      1     Data Scientist  $137K-$171K (Glassdoor est.)
# 2      2     Data Scientist  $137K-$171K (Glassdoor est.)
# 3      3     Data Scientist  $137K-$171K (Glassdoor est.)
# 4      4     Data Scientist  $137K-$171K (Glassdoor est.)
#
#                                      Job Description  Rating  \
# 0  Description\n\nThe Senior Data Scientist is re...     3.1
# 1  Secure our Nation, Ignite your Future\n\nJoin ...     4.2
# 2  Overview\n\n\nAnalysis Group is one of the lar...     3.8
# 3  JOB DESCRIPTION:\n\nDo you have a passion for ...     3.5
# 4  Data Scientist\nAffinity Solutions / Marketing...     2.9
#
#               Company Name       Location            Headquarters  \
# 0         Healthfirst\n3.1   New York, NY            New York, NY
# 1             ManTech\n4.2  Chantilly, VA             Herndon, VA
# ...

# %%
#Company name

df2['company_txt'] = df2.apply(lambda x: x['Company Name'] if x['Rating'] < 0 else x['Company Name'][:-3], axis=1)
df2['company_txt'] = df2['company_txt'].apply(lambda x: x.replace('\n', ' '))
df2.head(10)
# Out:
#    index                                 Job Title  \
# 0      0                         Sr Data Scientist
# 1      1                            Data Scientist
# 2      2                            Data Scientist
# 3      3                            Data Scientist
# 4      4                            Data Scientist
# 5      5                            Data Scientist
# 6      6  Data Scientist / Machine Learning Expert
# 7      7                            Data Scientist
# 8      8          Staff Data Scientist - Analytics
# 9      9                            Data Scientist
#
#                 Salary Estimate  \
# 0  $137K-$171K (Glassdoor est.)
# 1  $137K-$171K (Glassdoor est.)
# 2  $137K-$171K (Glassdoor est.)
# 3  $137K-$171K (Glassdoor est.)
# 4  $137K-$171K (Glassdoor est.)
# 5  $137K-$171K (Glassdoor est.)
# 6  $137K-$171K (Glassdoor est.)
# 7  $137K-$171K (Glassdoor est.)
# 8  $137K-$171K (Glassdoor est.)
# 9  $137K-$171K (Glassdoor est.)
#
# ...

# %%
#state field

df2['city'] = df2['Location'].apply(lambda x: x.split(',')[0])
df2['state'] = df2['Location'].apply(lambda x: x.split(',')[-1])
df2.head()
# Out:
#    index          Job Title               Salary Estimate  \
# 0      0  Sr Data Scientist  $137K-$171K (Glassdoor est.)
# 1      1     Data Scientist  $137K-$171K (Glassdoor est.)
# 2      2     Data Scientist  $137K-$171K (Glassdoor est.)
# 3      3     Data Scientist  $137K-$171K (Glassdoor est.)
# 4      4     Data Scientist  $137K-$171K (Glassdoor est.)
#
#                                      Job Description  Rating  \
# 0  Description\n\nThe Senior Data Scientist is re...     3.1
# 1  Secure our Nation, Ignite your Future\n\nJoin ...     4.2
# 2  Overview\n\n\nAnalysis Group is one of the lar...     3.8
# 3  JOB DESCRIPTION:\n\nDo you have a passion for ...     3.5
# 4  Data Scientist\nAffinity Solutions / Marketing...     2.9
#
#               Company Name       Location            Headquarters  \
# 0         Healthfirst\n3.1   New York, NY            New York, NY
# 1             ManTech\n4.2  Chantilly, VA             Herndon, VA
# ...

# %%
#is the location the same as that of the company headquarters

df2['same_state'] = df2.apply(lambda x: 1 if x['Location'] == x['Headquarters'] else 0, axis=1)
df2.head()
# Out:
#    index          Job Title               Salary Estimate  \
# 0      0  Sr Data Scientist  $137K-$171K (Glassdoor est.)
# 1      1     Data Scientist  $137K-$171K (Glassdoor est.)
# 2      2     Data Scientist  $137K-$171K (Glassdoor est.)
# 3      3     Data Scientist  $137K-$171K (Glassdoor est.)
# 4      4     Data Scientist  $137K-$171K (Glassdoor est.)
#
#                                      Job Description  Rating  \
# 0  Description\n\nThe Senior Data Scientist is re...     3.1
# 1  Secure our Nation, Ignite your Future\n\nJoin ...     4.2
# 2  Overview\n\n\nAnalysis Group is one of the lar...     3.8
# 3  JOB DESCRIPTION:\n\nDo you have a passion for ...     3.5
# 4  Data Scientist\nAffinity Solutions / Marketing...     2.9
#
#               Company Name       Location            Headquarters  \
# 0         Healthfirst\n3.1   New York, NY            New York, NY
# 1             ManTech\n4.2  Chantilly, VA             Herndon, VA
# ...

# %%
#Age of the company

df2['age'] = df2['Founded'].apply(lambda x: x if x<1 else 2023 - x)
df2.head()
# Out:
#    index          Job Title               Salary Estimate  \
# 0      0  Sr Data Scientist  $137K-$171K (Glassdoor est.)
# 1      1     Data Scientist  $137K-$171K (Glassdoor est.)
# 2      2     Data Scientist  $137K-$171K (Glassdoor est.)
# 3      3     Data Scientist  $137K-$171K (Glassdoor est.)
# 4      4     Data Scientist  $137K-$171K (Glassdoor est.)
#
#                                      Job Description  Rating  \
# 0  Description\n\nThe Senior Data Scientist is re...     3.1
# 1  Secure our Nation, Ignite your Future\n\nJoin ...     4.2
# 2  Overview\n\n\nAnalysis Group is one of the lar...     3.8
# 3  JOB DESCRIPTION:\n\nDo you have a passion for ...     3.5
# 4  Data Scientist\nAffinity Solutions / Marketing...     2.9
#
#               Company Name       Location            Headquarters  \
# 0         Healthfirst\n3.1   New York, NY            New York, NY
# 1             ManTech\n4.2  Chantilly, VA             Herndon, VA
# ...

# %%
#parse the Job description
df2['python'] = df2['Job Description'].apply(lambda x: 1 if 'python' in x.lower() else 0)
df2['excel'] = df2['Job Description'].apply(lambda x: 1 if 'excel' in x.lower() else 0)
df2['aws'] = df2['Job Description'].apply(lambda x: 1 if 'aws' in x.lower() else 0)
df2['tableau'] = df2['Job Description'].apply(lambda x: 1 if 'tableau' in x.lower() else 0)
df2['spark'] = df2['Job Description'].apply(lambda x: 1 if 'spark' in x.lower() else 0)

df2.head()
# Out:
#    index          Job Title               Salary Estimate  \
# 0      0  Sr Data Scientist  $137K-$171K (Glassdoor est.)
# 1      1     Data Scientist  $137K-$171K (Glassdoor est.)
# 2      2     Data Scientist  $137K-$171K (Glassdoor est.)
# 3      3     Data Scientist  $137K-$171K (Glassdoor est.)
# 4      4     Data Scientist  $137K-$171K (Glassdoor est.)
#
#                                      Job Description  Rating  \
# 0  Description\n\nThe Senior Data Scientist is re...     3.1
# 1  Secure our Nation, Ignite your Future\n\nJoin ...     4.2
# 2  Overview\n\n\nAnalysis Group is one of the lar...     3.8
# 3  JOB DESCRIPTION:\n\nDo you have a passion for ...     3.5
# 4  Data Scientist\nAffinity Solutions / Marketing...     2.9
#
#               Company Name       Location            Headquarters  \
# 0         Healthfirst\n3.1   New York, NY            New York, NY
# 1             ManTech\n4.2  Chantilly, VA             Herndon, VA
# ...

# %%
#function to extract value counts of skills columns

def value(x):
    return df2[x].value_counts()

# %%
#create a separate dataframe for the desired skills

df_skills = pd.DataFrame({"Python": value('python'), "Excel": value('excel'), "Tableau": value('tableau'), "AWS": value('aws'), "Spark": value('spark')})
df_skills = df_skills.transpose()
df_skills.rename(columns = {0: 'No', 1:'Yes'}, inplace=True)
df_skills
# Out:
#           No  Yes
# Python   181  491
# Excel    376  296
# Tableau  549  123
# AWS      498  174
# Spark    483  189

# %%
df_skills['percentage'] = df_skills['Yes']*100/(df_skills['No']+df_skills['Yes'])
df_skills['percentage'] = df_skills['percentage'].round(2)
df_skills.sort_values('percentage', ascending=False, inplace=True)
df_skills
# Out:
#           No  Yes  percentage
# Python   181  491       73.07
# Excel    376  296       44.05
# Spark    483  189       28.12
# AWS      498  174       25.89
# Tableau  549  123       18.30

# %%
df2.to_csv('salary_cleaned_set.csv', index=False)
